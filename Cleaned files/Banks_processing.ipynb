# %%
import twarc
import os
import matplotlib.pyplot as plt
import pandas as pd
import re
import nltk
import requests
from transformers import pipeline
import string

nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('english')
stop_words.append('uh')
puncs = string.punctuation
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/korfoo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Process the downloaded tweet json to csv files

# %%
all_columns=['conversation_id', 'id','author_id','text','in_reply_to_user_id']
for file in os.listdir("Banks_conv"):
    if file.split(".")[1]=="json":
        print("--------------Processing file {0}--------------".format(file))
        df=pd.read_json(os.path.join("Banks_conv",file),lines=True)
        all_tweets=[]
        i=100
        for line in df['data']:
            for tweet in line:
                tweet_info=[]

                for column in all_columns:
                    tweet_info.append(tweet[column])

                if tweet.get('referenced_tweets','')!='':
                    if tweet['referenced_tweets'][0]['type']=='replied_to':
                        tweet_info.append(tweet['referenced_tweets'][0]['id'])
                    else:
                        tweet_info.append('')
                else:
                    tweet_info.append('')
                
                if tweet.get('attachments','')!='':
                    tweet_info.append('1')
                else:
                    tweet_info.append('0')

                all_tweets.append(tweet_info)

            if len(all_tweets)>i:
                print("--------------Processed more than {0} tweets--------------".format(i))
                i=i*10

        for line in df['includes']:
            for tweet in line['tweets']:
                tweet_info=[]

                for column in all_columns:
                    tweet_info.append(tweet.get(column,''))

                if tweet.get('referenced_tweets','')!='':
                    if tweet['referenced_tweets'][0]['type']=='replied_to':
                        tweet_info.append(tweet['referenced_tweets'][0]['id'])
                    else:
                        tweet_info.append('')
                else:
                    tweet_info.append('')
                
                if tweet.get('attachments','')!='':
                    tweet_info.append('1')
                else:
                    tweet_info.append('0')
                
                all_tweets.append(tweet_info)

            if len(all_tweets)>i:
                print("--------------Processed more than {0} tweets--------------".format(i))
                i=i*10

        df_out = pd.DataFrame(all_tweets,columns=all_columns+['replied_to', 'attachment'])
        df_out = df_out.drop_duplicates().copy()
        df_out.to_csv("Banks_conv/"+file.split(".")[0]+".csv", index=False)
# Out:
# --------------Processing file WellsFargo.json--------------
# --------------Processed more than 100 tweets--------------
# --------------Processed more than 1000 tweets--------------
# --------------Processed more than 10000 tweets--------------
# --------------Processed more than 100000 tweets--------------
# --------------Processing file DeutscheBank.json--------------
# --------------Processed more than 100 tweets--------------
# --------------Processed more than 1000 tweets--------------
# --------------Processed more than 10000 tweets--------------
# --------------Processing file BofA_Help.json--------------
# --------------Processed more than 100 tweets--------------
# --------------Processed more than 1000 tweets--------------
# --------------Processed more than 10000 tweets--------------
# --------------Processing file jpmorgan.json--------------
# --------------Processed more than 100 tweets--------------
# --------------Processed more than 1000 tweets--------------
# --------------Processed more than 10000 tweets--------------
# --------------Processing file Citi.json--------------
# --------------Processed more than 100 tweets--------------
# --------------Processed more than 1000 tweets--------------
# --------------Processed more than 10000 tweets--------------

# %% [markdown]
# ## Perform labeling for answered/unanswered tweets

# %%
#Dictionary to store Banks ids
Banks_dict = {
        "WellsFargo":"1178011",
        "jpmorgan":"1155522630",
        "BofA_Help":"18735040",
        "Citi":"79320096",
        "DeutscheBank":"41330603",
}

# %%
def do_labeling(org_ids):

    #DataFrame to store all labeled replies related to our task
    all_replies = pd.DataFrame()

    for file in os.listdir('Banks_conv'):
        if file.split('.')[1]=='csv':
            NGO_name = file.split('.')[0]
            NGO_id = org_ids[NGO_name]

            #added terminator to fix tokenizer error for some files
            df = pd.read_csv("Banks_conv/{0}".format(file), lineterminator='\n', dtype='str')

            #get the tweets on which users got replies
            ngo_replied_to_ids = df[(df["author_id"] == NGO_id) & (df["in_reply_to_user_id"] != NGO_id)]["replied_to"].dropna()
            ngo_replied_to = df[df['id'].isin(ngo_replied_to_ids)].dropna()
            ngo_replied_to["label"] = 1

            #get the tweets on which ngo didn't reply
            replies_to_ngo = df[(df["in_reply_to_user_id"]==NGO_id) & (df["author_id"]!=NGO_id)]
            replies_to_ngo = replies_to_ngo[~replies_to_ngo['id'].isin(ngo_replied_to_ids)].dropna()
            replies_to_ngo["label"] = 0

            #concatenate these tweets together
            all_ngo_replies = pd.concat([replies_to_ngo, ngo_replied_to]).reset_index(drop=True)
            all_ngo_replies["relatedOrg"] = NGO_name
            
            #add current ngo data to global df
            all_replies = pd.concat([all_replies, all_ngo_replies]).reset_index(drop=True)

            print("processed file: {0}".format(file))
            
    all_replies.to_csv("Banks_conv/labeled_data.csv")

# %%
#label banks
do_labeling(Banks_dict)
# Out:
# processed file: WellsFargo.csv
# processed file: DeutscheBank.csv
# processed file: BofA_Help.csv
# processed file: Citi.csv
# processed file: jpmorgan.csv

# %%
df = pd.read_csv("Banks_conv/labeled_data.csv", index_col=0, dtype='str')
df.head(5)
# Out:
#        conversation_id                   id            author_id  \
# 0  1256647208256102400  1257392415062863877  1254487703334219776
# 1  1256647208256102400  1257350048414924801            342060815
# 2   953819605587415041   954374335141003269   951483180346892288
# 3   953819605587415041   954374200994627584   951483180346892288
# 4   953819605587415041   954351324648402944           2400707515
#
#                                                 text in_reply_to_user_id  \
# 0  @WellsFargo @jordanyebe Thats a bullshit phone...             1178011
# 1  @WellsFargo Well this weekend I tried to make ...             1178011
# 2  @WellsFargo Wells Fargo deleted my other comme...             1178011
# 3        @WellsFargo Boycott Wells Fargo #buybitcoin             1178011
# 4                        @WellsFargo #fuckwellsfargo             1178011
#
#             replied_to attachment label  relatedNGO
# 0  1257349230248820741          0     0  WellsFargo
# 1  1257349230248820741          0     0  WellsFargo
# 2   953819605587415041          0     0  WellsFargo
# 3   953819605587415041          0     0  WellsFargo
# 4   953819605587415041          0     0  WellsFargo

# %%
#check statistics
df.groupby([df.label, df.relatedOrg]).count()
# Out:
#                     conversation_id     id  author_id   text  \
# label relatedNGO
# 0     BofA_Help                 330    330        330    330
#       Citi                     8819   8819       8819   8819
#       DeutscheBank             5715   5715       5715   5715
#       WellsFargo               3393   3393       3393   3393
#       jpmorgan                10292  10292      10292  10292
# 1     BofA_Help                 594    594        594    594
#       Citi                        1      1          1      1
#       DeutscheBank              584    584        584    584
#       WellsFargo                925    925        925    925
#       jpmorgan                   61     61         61     61
#
#                     in_reply_to_user_id  replied_to  attachment
# label relatedNGO
# 0     BofA_Help                     330         330         330
#       Citi                         8819        8819        8819
#       DeutscheBank                 5715        5715        5715
#       WellsFargo                   3393        3393        3393
#       jpmorgan                    10292       10292       10292
# 1     BofA_Help                     594         594         594
#       Citi                            1           1           1
#       DeutscheBank                  584         584         584
#       WellsFargo                    925         925         925
#       jpmorgan                       61          61          61

# %%
#delete citi bank, no use in it
df = df[df.relatedOrg != "Citi"]
df.to_csv("Banks_conv/labeled_no_city.csv")

# %% [markdown]
# ## Process downloaded authors info

# %%
#save user ids to download through twarc
users = pd.DataFrame(df["author_id"].unique())
users.to_csv("Banks_conv/users_ids.txt", index = False, header=False)

# %%
#Process the needed info to csv
df=pd.read_json("Banks_conv/users.json",lines=True)
all_users=[]
public_columns=['followers_count', 'following_count','tweet_count']
additional_columns=['id','name', 'username', 'description','created_at']
for line in df['data']:
    for user in line:

        user_info=[]        
        for column in public_columns:
            try:
                user_info.append(user['public_metrics'][column])
            except:
                print(user)
        for column in additional_columns:
            user_info.append(user[column])

        all_users.append(user_info)

users = pd.DataFrame(all_users,columns=public_columns+additional_columns)
users = users.drop_duplicates().copy()
users = users.drop_duplicates(["id"]).copy()
users.to_csv("Banks_conv/users.csv", index=False)

# %%
#read df
df = pd.read_csv("Banks_conv/labeled_no_city.csv", index_col=0, dtype='str')
df
# Out:
#            conversation_id                   id            author_id  \
# 0      1256647208256102400  1257392415062863877  1254487703334219776
# 1      1256647208256102400  1257350048414924801            342060815
# 2       953819605587415041   954374335141003269   951483180346892288
# 3       953819605587415041   954374200994627584   951483180346892288
# 4       953819605587415041   954351324648402944           2400707515
# ...                    ...                  ...                  ...
# 30709   658707029549293568   661588595866787840             57460933
# 30710  1074984368634966016  1075021118711435265            259232385
# 30711   688242664693579776   688404765034856456             68163076
# 30712   919972865847545856   919981362718937091            257400981
# 30713  1093262673695789056  1093299055357247488           2945484446
#
#                                                     text in_reply_to_user_id  \
# 0      @WellsFargo @jordanyebe Thats a bullshit phone...             1178011
# 1      @WellsFargo Well this weekend I tried to make ...             1178011
# 2      @WellsFargo Wells Fargo deleted my other comme...             1178011
# 3            @WellsFargo Boycott Wells Fargo #buybitcoin             1178011
# 4                            @WellsFargo #fuckwellsfargo             1178011
# ...                                                  ...                 ...
# 30709  @jpmorgan @BarbicanCentre @TheRSC I've got tic...          1155522630
# 30710                                    @jpmorgan #stop          1155522630
# 30711  @DeeeeBlike @jpmorgan this needs to be address...            70063328
# 30712    @TracieFain @jpmorgan He should be fired ! #pig           355722698
# 30713          @jpmorgan @NetworkBway @tonygoldwyn #stop          1155522630
#
#                 replied_to attachment label  relatedNGO
# 0      1257349230248820741          0     0  WellsFargo
# 1      1257349230248820741          0     0  WellsFargo
# 2       953819605587415041          0     0  WellsFargo
# 3       953819605587415041          0     0  WellsFargo
# 4       953819605587415041          0     0  WellsFargo
# ...                    ...        ...   ...         ...
# 30709   658707029549293568          0     1    jpmorgan
# 30710  1074984368634966016          0     1    jpmorgan
# 30711   688242664693579776          0     1    jpmorgan
# 30712   919972865847545856          0     1    jpmorgan
# 30713  1093262673695789056          0     1    jpmorgan
#
# [21894 rows x 9 columns]

# %%
#merge with existing tweet df
df_merged = df.merge(users, left_on='author_id', right_on='id', how='left')
df_merged = df_merged.drop(['name', 'description', 'created_at', 'id_y', 'username'], axis = 1)
df_merged = df_merged.rename(columns={"id_x":"id", "followers_count":"author_followers", "following_count":"author_following", "tweet_count":"author_tweets"})
df_merged
# Out:
#            conversation_id                   id            author_id  \
# 0      1256647208256102400  1257392415062863877  1254487703334219776
# 1      1256647208256102400  1257350048414924801            342060815
# 2       953819605587415041   954374335141003269   951483180346892288
# 3       953819605587415041   954374200994627584   951483180346892288
# 4       953819605587415041   954351324648402944           2400707515
# ...                    ...                  ...                  ...
# 21889   658707029549293568   661588595866787840             57460933
# 21890  1074984368634966016  1075021118711435265            259232385
# 21891   688242664693579776   688404765034856456             68163076
# 21892   919972865847545856   919981362718937091            257400981
# 21893  1093262673695789056  1093299055357247488           2945484446
#
#                                                     text in_reply_to_user_id  \
# 0      @WellsFargo @jordanyebe Thats a bullshit phone...             1178011
# 1      @WellsFargo Well this weekend I tried to make ...             1178011
# 2      @WellsFargo Wells Fargo deleted my other comme...             1178011
# 3            @WellsFargo Boycott Wells Fargo #buybitcoin             1178011
# 4                            @WellsFargo #fuckwellsfargo             1178011
# ...                                                  ...                 ...
# 21889  @jpmorgan @BarbicanCentre @TheRSC I've got tic...          1155522630
# 21890                                    @jpmorgan #stop          1155522630
# 21891  @DeeeeBlike @jpmorgan this needs to be address...            70063328
# 21892    @TracieFain @jpmorgan He should be fired ! #pig           355722698
# 21893          @jpmorgan @NetworkBway @tonygoldwyn #stop          1155522630
#
#                 replied_to attachment label  relatedNGO  author_followers  \
# 0      1257349230248820741          0     0  WellsFargo               0.0
# 1      1257349230248820741          0     0  WellsFargo            1374.0
# 2       953819605587415041          0     0  WellsFargo             751.0
# 3       953819605587415041          0     0  WellsFargo             751.0
# 4       953819605587415041          0     0  WellsFargo               0.0
# ...                    ...        ...   ...         ...               ...
# 21889   658707029549293568          0     1    jpmorgan           12849.0
# 21890  1074984368634966016          0     1    jpmorgan             658.0
# 21891   688242664693579776          0     1    jpmorgan             486.0
# 21892   919972865847545856          0     1    jpmorgan           19517.0
# 21893  1093262673695789056          0     1    jpmorgan             168.0
#
#        author_following  author_tweets       username
# 0                   8.0          159.0     Ki41703898
# 1                 719.0       128221.0     JordanYebe
# 2                2203.0         7727.0  coinblockhead
# 3                2203.0         7727.0  coinblockhead
# 4                   2.0            4.0     bas33dgood
# ...                 ...            ...            ...
# 21889            8997.0        31189.0    ZoeParamour
# 21890             719.0        17369.0    arixcalorna
# 21891             540.0        62667.0      Mista_Ace
# 21892             788.0          794.0    SanaH_Sport
# 21893             172.0         2864.0    Alisa87MAGA
#
# [21894 rows x 13 columns]

# %% [markdown]
# ## Process downloaded info of users in reply to whom the tweet was written

# %%
#get the user id whom the tweet was addressed to download data from twarc
replied_users = pd.DataFrame(df["in_reply_to_user_id"].unique())
replied_users.to_csv("Banks_conv/replied_users_ids.txt", index = False, header=False)

# %%
#Process the needed info to csv
df=pd.read_json("Banks_conv/replied_users.json",lines=True)
all_users=[]
public_columns=['followers_count', 'following_count','tweet_count']
additional_columns=['id','name', 'username', 'description','created_at']
for line in df['data']:
    for user in line:

        user_info=[]        
        for column in public_columns:
            try:
                user_info.append(user['public_metrics'][column])
            except:
                print(user)
        for column in additional_columns:
            user_info.append(user[column])

        all_users.append(user_info)

replied_users = pd.DataFrame(all_users,columns=public_columns+additional_columns)
replied_users = replied_users.drop_duplicates().copy()
replied_users = replied_users.drop_duplicates(["id"]).copy()
replied_users.to_csv("Banks_conv/replied_users.csv", index=False)

# %%
#merge with existing tweet df
df_merged = df_merged.merge(replied_users, left_on='in_reply_to_user_id', right_on='id', how='left')
df_merged = df_merged.drop(['name', 'description', 'created_at', 'id_y'], axis = 1)
df_merged = df_merged.rename(columns={"id_x":"id", "followers_count":"replied_followers", "following_count":"replied_following", "tweet_count":"replied_tweets", "username":"replied_name"})
df_merged
# Out:
#            conversation_id                   id            author_id  \
# 0      1256647208256102400  1257392415062863877  1254487703334219776
# 1      1256647208256102400  1257350048414924801            342060815
# 2       953819605587415041   954374335141003269   951483180346892288
# 3       953819605587415041   954374200994627584   951483180346892288
# 4       953819605587415041   954351324648402944           2400707515
# ...                    ...                  ...                  ...
# 21889   658707029549293568   661588595866787840             57460933
# 21890  1074984368634966016  1075021118711435265            259232385
# 21891   688242664693579776   688404765034856456             68163076
# 21892   919972865847545856   919981362718937091            257400981
# 21893  1093262673695789056  1093299055357247488           2945484446
#
#                                                     text in_reply_to_user_id  \
# 0      @WellsFargo @jordanyebe Thats a bullshit phone...             1178011
# 1      @WellsFargo Well this weekend I tried to make ...             1178011
# 2      @WellsFargo Wells Fargo deleted my other comme...             1178011
# 3            @WellsFargo Boycott Wells Fargo #buybitcoin             1178011
# 4                            @WellsFargo #fuckwellsfargo             1178011
# ...                                                  ...                 ...
# 21889  @jpmorgan @BarbicanCentre @TheRSC I've got tic...          1155522630
# 21890                                    @jpmorgan #stop          1155522630
# 21891  @DeeeeBlike @jpmorgan this needs to be address...            70063328
# 21892    @TracieFain @jpmorgan He should be fired ! #pig           355722698
# 21893          @jpmorgan @NetworkBway @tonygoldwyn #stop          1155522630
#
#                 replied_to attachment label  relatedNGO  author_followers  \
# 0      1257349230248820741          0     0  WellsFargo               0.0
# 1      1257349230248820741          0     0  WellsFargo            1374.0
# 2       953819605587415041          0     0  WellsFargo             751.0
# 3       953819605587415041          0     0  WellsFargo             751.0
# 4       953819605587415041          0     0  WellsFargo               0.0
# ...                    ...        ...   ...         ...               ...
# 21889   658707029549293568          0     1    jpmorgan           12849.0
# 21890  1074984368634966016          0     1    jpmorgan             658.0
# 21891   688242664693579776          0     1    jpmorgan             486.0
# 21892   919972865847545856          0     1    jpmorgan           19517.0
# 21893  1093262673695789056          0     1    jpmorgan             168.0
#
#        author_following  author_tweets     username_x  replied_followers  \
# 0                   8.0          159.0     Ki41703898           347533.0
# 1                 719.0       128221.0     JordanYebe           347533.0
# 2                2203.0         7727.0  coinblockhead           347533.0
# 3                2203.0         7727.0  coinblockhead           347533.0
# 4                   2.0            4.0     bas33dgood           347533.0
# ...                 ...            ...            ...                ...
# 21889            8997.0        31189.0    ZoeParamour           726641.0
# 21890             719.0        17369.0    arixcalorna           726641.0
# 21891             540.0        62667.0      Mista_Ace             3684.0
# 21892             788.0          794.0    SanaH_Sport               31.0
# 21893             172.0         2864.0    Alisa87MAGA           726641.0
#
#        replied_following  replied_tweets  username_y
# 0                  149.0         59749.0  WellsFargo
# 1                  149.0         59749.0  WellsFargo
# 2                  149.0         59749.0  WellsFargo
# 3                  149.0         59749.0  WellsFargo
# 4                  149.0         59749.0  WellsFargo
# ...                  ...             ...         ...
# 21889               49.0          8117.0    jpmorgan
# 21890               49.0          8117.0    jpmorgan
# 21891             3016.0        169325.0  DeeeeBlike
# 21892              370.0           588.0  TracieFain
# 21893               49.0          8117.0    jpmorgan
#
# [21894 rows x 17 columns]

# %%
#save the data
df_merged.to_csv("Banks_conv/labeled_with_users.csv")

# %% [markdown]
# ## Add additional features

# %%
df = pd.read_csv("Banks_conv/labeled_with_users.csv", dtype='str', index_col= 0)
df.head(5)
# Out:
#        conversation_id                   id            author_id  \
# 0  1256647208256102400  1257392415062863877  1254487703334219776
# 1  1256647208256102400  1257350048414924801            342060815
# 2   953819605587415041   954374335141003269   951483180346892288
# 3   953819605587415041   954374200994627584   951483180346892288
# 4   953819605587415041   954351324648402944           2400707515
#
#                                                 text in_reply_to_user_id  \
# 0  @WellsFargo @jordanyebe Thats a bullshit phone...             1178011
# 1  @WellsFargo Well this weekend I tried to make ...             1178011
# 2  @WellsFargo Wells Fargo deleted my other comme...             1178011
# 3        @WellsFargo Boycott Wells Fargo #buybitcoin             1178011
# 4                        @WellsFargo #fuckwellsfargo             1178011
#
#             replied_to attachment label  relatedNGO author_followers  \
# 0  1257349230248820741          0     0  WellsFargo              0.0
# 1  1257349230248820741          0     0  WellsFargo           1374.0
# 2   953819605587415041          0     0  WellsFargo            751.0
# 3   953819605587415041          0     0  WellsFargo            751.0
# 4   953819605587415041          0     0  WellsFargo              0.0
#
#   author_following author_tweets replied_followers replied_following  \
# 0              8.0         159.0          347533.0             149.0
# 1            719.0      128221.0          347533.0             149.0
# 2           2203.0        7727.0          347533.0             149.0
# 3           2203.0        7727.0          347533.0             149.0
# 4              2.0           4.0          347533.0             149.0
#
#   replied_tweets replied_name
# 0        59749.0   WellsFargo
# 1        59749.0   WellsFargo
# 2        59749.0   WellsFargo
# 3        59749.0   WellsFargo
# 4        59749.0   WellsFargo

# %%
#drop rows with uncorrectly processed label if such exist
df = df[df['label'].notna()]
df = df.reset_index(drop=True)

# %%
#tokenize the text
df["text_new"]=df["text"].apply(lambda x: [word for word in [re.sub(f"[{puncs}]","",token).lower() for token in x.split() if token[0]!='@'] if word not in stop_words+['rt','']])
#number of user mentions "@" in a text
df["num_mentions"]=df["text"].apply(lambda x: len([i for i in x.split() if i[0]=='@']))
#number of links in a text
df["num_links"]=df["text"].apply(lambda x: len([i for i in x.split() if 'http'in i]))
#number of words in original text
df["num_full_words"] = df.text.apply(lambda x: len(x.split(' ')))
#number of words in tokenized text
df["num_tokenized_words"] = df.text_new.apply(lambda x: len(x))
#number of hashtags in text
df["num_hashtags"]=df.text.apply(lambda x: len([i for i in x.split() if i[0]=='#']))
#number of related_NGO mentions in a tweet
df["num_NGO_mentions"]=df.apply(lambda x: x.text.split(" ").count(f"@{x.relatedNGO}"), axis=1)
#number of exclamation marks in text
df["num_exclamation"]=df.apply(lambda x: x.text.count("!"), axis=1)
#number of question marks in a tweet
df["num_question"]=df.apply(lambda x: x.text.count("?"), axis=1)
#if the tweet was a retweeted one
df["retweet"] = df.text.apply(lambda x: 1 if x[:2]=="RT" else 0)
#number of characters in original text
df["num_characters"] = df.text.apply(lambda x: len(x))

df
# Out:
#            conversation_id                   id            author_id  \
# 0      1256647208256102400  1257392415062863877  1254487703334219776
# 1      1256647208256102400  1257350048414924801            342060815
# 2       953819605587415041   954374335141003269   951483180346892288
# 3       953819605587415041   954374200994627584   951483180346892288
# 4       953819605587415041   954351324648402944           2400707515
# ...                    ...                  ...                  ...
# 21889   658707029549293568   661588595866787840             57460933
# 21890  1074984368634966016  1075021118711435265            259232385
# 21891   688242664693579776   688404765034856456             68163076
# 21892   919972865847545856   919981362718937091            257400981
# 21893  1093262673695789056  1093299055357247488           2945484446
#
#                                                     text in_reply_to_user_id  \
# 0      @WellsFargo @jordanyebe Thats a bullshit phone...             1178011
# 1      @WellsFargo Well this weekend I tried to make ...             1178011
# 2      @WellsFargo Wells Fargo deleted my other comme...             1178011
# 3            @WellsFargo Boycott Wells Fargo #buybitcoin             1178011
# 4                            @WellsFargo #fuckwellsfargo             1178011
# ...                                                  ...                 ...
# 21889  @jpmorgan @BarbicanCentre @TheRSC I've got tic...          1155522630
# 21890                                    @jpmorgan #stop          1155522630
# 21891  @DeeeeBlike @jpmorgan this needs to be address...            70063328
# 21892    @TracieFain @jpmorgan He should be fired ! #pig           355722698
# 21893          @jpmorgan @NetworkBway @tonygoldwyn #stop          1155522630
#
#                 replied_to attachment label  relatedNGO author_followers  ...  \
# 0      1257349230248820741          0     0  WellsFargo              0.0  ...
# 1      1257349230248820741          0     0  WellsFargo           1374.0  ...
# 2       953819605587415041          0     0  WellsFargo            751.0  ...
# 3       953819605587415041          0     0  WellsFargo            751.0  ...
# 4       953819605587415041          0     0  WellsFargo              0.0  ...
# ...                    ...        ...   ...         ...              ...  ...
# 21889   658707029549293568          0     1    jpmorgan          12849.0  ...
# 21890  1074984368634966016          0     1    jpmorgan            658.0  ...
# 21891   688242664693579776          0     1    jpmorgan            486.0  ...
# 21892   919972865847545856          0     1    jpmorgan          19517.0  ...
# 21893  1093262673695789056          0     1    jpmorgan            168.0  ...
#
#       replied_name                                           text_new  \
# 0       WellsFargo  [thats, bullshit, phone, number, hung, 30, min...
# 1       WellsFargo  [well, weekend, tried, make, 550, purchase, de...
# 2       WellsFargo  [wells, fargo, deleted, comments, anyways, sca...
# 3       WellsFargo                [boycott, wells, fargo, buybitcoin]
# 4       WellsFargo                                   [fuckwellsfargo]
# ...            ...                                                ...
# 21889     jpmorgan                 [ive, got, tickets, next, tuesday]
# 21890     jpmorgan                                             [stop]
# 21891   DeeeeBlike                           [needs, addressed, asap]
# 21892   TracieFain                                       [fired, pig]
# 21893     jpmorgan                                             [stop]
#
#       num_mentions num_links num_full_words num_tokenized_words num_hashtags  \
# 0                2         0             21                  12            1
# 1                1         0             39                  19            0
# 2                1         0             20                   9            0
# 3                1         0              5                   4            1
# 4                1         0              2                   1            1
# ...            ...       ...            ...                 ...          ...
# 21889            3         0              9                   5            0
# 21890            1         0              2                   1            1
# 21891            2         0              8                   3            0
# 21892            2         0              8                   2            1
# 21893            3         0              4                   1            1
#
#        num_NGO_mentions  num_exclamation  num_question
# 0                     1                0             0
# 1                     1                0             1
# 2                     1                0             0
# 3                     1                0             0
# 4                     1                0             0
# ...                 ...              ...           ...
# 21889                 1                1             0
# 21890                 1                0             0
# 21891                 1                0             0
# 21892                 1                1             0
# 21893                 1                0             0
#
# [21894 rows x 25 columns]

# %%
#save the data
df.to_csv("Banks_conv/Banks_extended_features.csv")

# %% [markdown]
# ## Sentiment analysis of tweets

# %%
#set hugging face model
model = "cardiffnlp/twitter-roberta-base-sentiment-latest"

#set the pipeline
sentiment_pipeline = pipeline("sentiment-analysis", model = model, tokenizer = model)

#check output for one of the tweets
sentiment_pipeline(df["text"][0])[0]["label"]
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 'negative'

# %%
#get sentiment while treating errors
def set_sentimet(text):
    try:
        sentiment = sentiment_pipeline(text)[0]["label"]
    except:
        sentiment = "Error"
    return sentiment

# %%
#add sentiment feature to the dataset
df["sentiment"] = df.text.apply(lambda x: set_sentimet(x))
df = df[df.sentiment!="Error"]
df
# Out:
#            conversation_id                   id            author_id  \
# 0      1256647208256102400  1257392415062863877  1254487703334219776
# 1      1256647208256102400  1257350048414924801            342060815
# 2       953819605587415041   954374335141003269   951483180346892288
# 3       953819605587415041   954374200994627584   951483180346892288
# 4       953819605587415041   954351324648402944           2400707515
# ...                    ...                  ...                  ...
# 21889   658707029549293568   661588595866787840             57460933
# 21890  1074984368634966016  1075021118711435265            259232385
# 21891   688242664693579776   688404765034856456             68163076
# 21892   919972865847545856   919981362718937091            257400981
# 21893  1093262673695789056  1093299055357247488           2945484446
#
#                                                     text in_reply_to_user_id  \
# 0      @WellsFargo @jordanyebe Thats a bullshit phone...             1178011
# 1      @WellsFargo Well this weekend I tried to make ...             1178011
# 2      @WellsFargo Wells Fargo deleted my other comme...             1178011
# 3            @WellsFargo Boycott Wells Fargo #buybitcoin             1178011
# 4                            @WellsFargo #fuckwellsfargo             1178011
# ...                                                  ...                 ...
# 21889  @jpmorgan @BarbicanCentre @TheRSC I've got tic...          1155522630
# 21890                                    @jpmorgan #stop          1155522630
# 21891  @DeeeeBlike @jpmorgan this needs to be address...            70063328
# 21892    @TracieFain @jpmorgan He should be fired ! #pig           355722698
# 21893          @jpmorgan @NetworkBway @tonygoldwyn #stop          1155522630
#
#                 replied_to attachment label  relatedNGO author_followers  ...  \
# 0      1257349230248820741          0     0  WellsFargo              0.0  ...
# 1      1257349230248820741          0     0  WellsFargo           1374.0  ...
# 2       953819605587415041          0     0  WellsFargo            751.0  ...
# 3       953819605587415041          0     0  WellsFargo            751.0  ...
# 4       953819605587415041          0     0  WellsFargo              0.0  ...
# ...                    ...        ...   ...         ...              ...  ...
# 21889   658707029549293568          0     1    jpmorgan          12849.0  ...
# 21890  1074984368634966016          0     1    jpmorgan            658.0  ...
# 21891   688242664693579776          0     1    jpmorgan            486.0  ...
# 21892   919972865847545856          0     1    jpmorgan          19517.0  ...
# 21893  1093262673695789056          0     1    jpmorgan            168.0  ...
#
#                                                 text_new num_mentions  \
# 0      [thats, bullshit, phone, number, hung, 30, min...            2
# 1      [well, weekend, tried, make, 550, purchase, de...            1
# 2      [wells, fargo, deleted, comments, anyways, sca...            1
# 3                    [boycott, wells, fargo, buybitcoin]            1
# 4                                       [fuckwellsfargo]            1
# ...                                                  ...          ...
# 21889                 [ive, got, tickets, next, tuesday]            3
# 21890                                             [stop]            1
# 21891                           [needs, addressed, asap]            2
# 21892                                       [fired, pig]            2
# 21893                                             [stop]            3
#
#       num_links num_full_words num_tokenized_words num_hashtags  \
# 0             0             21                  12            1
# 1             0             39                  19            0
# 2             0             20                   9            0
# 3             0              5                   4            1
# 4             0              2                   1            1
# ...         ...            ...                 ...          ...
# 21889         0              9                   5            0
# 21890         0              2                   1            1
# 21891         0              8                   3            0
# 21892         0              8                   2            1
# 21893         0              4                   1            1
#
#       num_NGO_mentions  num_exclamation  num_question  sentiment
# 0                    1                0             0   negative
# 1                    1                0             1   negative
# 2                    1                0             0   negative
# 3                    1                0             0   negative
# 4                    1                0             0   negative
# ...                ...              ...           ...        ...
# 21889                1                1             0   positive
# 21890                1                0             0   negative
# 21891                1                0             0   negative
# 21892                1                1             0   negative
# 21893                1                0             0    neutral
#
# [21894 rows x 26 columns]

# %%
#save the data
df.to_csv("Banks_conv/Banks_extended_features.csv")
